# %%
🧪 SQL CONSTRAINTS – PRACTICE TASKS
📌 Use this database:

tcaw_ex

🟢 PRIMARY KEY
C1. Primary Key

Create a table users with:

user_id → Primary Key

username

email

created_at

🟢 COMPOSITE PRIMARY KEY
C2. Composite Primary Key

Create a table course_enrollments with:

student_id

course_id

enroll_date

👉 student_id + course_id together should be the primary key.

🟡 UNIQUE CONSTRAINT
C3. UNIQUE

Create a table employees_auth with:

emp_id (Primary Key)

email → UNIQUE

phone → UNIQUE

🔵 NULL / NOT NULL
C4. NOT NULL

Create a table products where:

product_id → Primary Key

product_name → NOT NULL

price → NOT NULL

description → NULL allowed

🟣 CHECK CONSTRAINT
C5. CHECK

Create a table students with:

student_id (Primary Key)

age → must be >= 18

gender → only 'M', 'F', 'O'

🔴 FOREIGN KEY (ON DELETE CASCADE)
C6. Foreign Key

Create two tables:

departments

dept_id (Primary Key)

dept_name

employees

emp_id (Primary Key)

emp_name

dept_id → Foreign Key

References departments(dept_id)

ON DELETE CASCADE

🔥 FOREIGN KEY SCENARIO TASK
C7.

Insert:

2 departments

3 employees linked to one department

Then:

Delete that department
👉 Observe what happens to employees.

🧠 SOFT DELETE (VERY IMPORTANT – REAL WORLD)
C8. Soft Delete Column

Create a table customers with:

customer_id (Primary Key)

customer_name

is_deleted → default 0

deleted_at → NULL

C9. Soft Delete Update

Write a query to soft delete customer with customer_id = 5.

C10. Fetch Active Records

Write a query to fetch only non-deleted customers.

🔥 INTERVIEW THINKING TASK (CRITICAL)
C11.

Explain:

When would you use soft delete instead of DELETE?

Write the query pattern used in production systems.

(Short explanation + query)

# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:root@localhost/

# %%
# %%sql
# show databases;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 10 rows affected.
# [('crud_ex',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('root',),
#  ('sakila',),
#  ('saud',),
#  ('sys',),
#  ('tcaw_ex',),
#  ('world',)]

# %%
# %%sql
# create database const_ex;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 1 rows affected.
# []

# %%
# %%sql
# #C1. Primary Key
# create table const_ex.primary (User_id INT primary key , username varchar(20),email varchar(50),created_at date);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# []

# %%
# %%sql
# insert into const_ex.primary values
# (1,'saud','saudjabarali@gmail.com','2026-01-19'),
# (2,'aysha','ayshaidris@gmail.com','2025-04-28');
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 2 rows affected.
# []

# %%
# %%sql
# insert into const_ex.primary values
# (2,'asdf','asdfghjkkkkkl','2025-10-22');
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# (mysql.connector.errors.IntegrityError) 1062 (23000): Duplicate entry '2' for key 'primary.PRIMARY'
# [SQL: insert into const_ex.primary values
# (2,'asdf','asdfghjkkkkkl','2025-10-22');]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
# %%sql
# select * from const_ex.primary;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 2 rows affected.
# [(1, 'saud', 'saudjabarali@gmail.com', datetime.date(2026, 1, 19)),
#  (2, 'aysha', 'ayshaidris@gmail.com', datetime.date(2025, 4, 28))]

# %%
# %%sql
# #C2. Composite Primary Key
# create table const_ex.conpokey (student_id int , course_id int , enroll_date date, primary key(student_id,course_id));
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# []

# %%
# %%sql
#
# insert into const_ex.conpokey values
# (2,102,'2025-12-10');
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# (mysql.connector.errors.IntegrityError) 1062 (23000): Duplicate entry '2-102' for key 'conpokey.PRIMARY'
# [SQL: insert into const_ex.conpokey values
# (2,102,'2025-12-10');]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
# %%sql
# select * from const_ex.conpokey;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 3 rows affected.
# [(1, 101, datetime.date(2025, 12, 10)),
#  (2, 101, datetime.date(2025, 12, 10)),
#  (2, 102, datetime.date(2025, 12, 10))]

# %%
# %%sql
# #C3. UNIQUE
# create table const_ex.uniquetab (User_id INT primary key , username varchar(20) unique,email varchar(50) unique,created_at date);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# []

# %%
# %%sql
# insert into const_ex.uniquetab values
# (2,'aysha','saudjabarali@gmail.com','2026-01-20');
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# (mysql.connector.errors.IntegrityError) 1062 (23000): Duplicate entry 'saudjabarali@gmail.com' for key 'uniquetab.email'
# [SQL: insert into const_ex.uniquetab values
# (2,'aysha','saudjabarali@gmail.com','2026-01-20');]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
# %%sql
# select * from const_ex.uniquetab;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 1 rows affected.
# [(1, 'saud', 'saudjabarali@gmail.com', datetime.date(2026, 1, 20))]

# %%
# %%sql
# desc const_ex.uniquetab;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 4 rows affected.
# [('User_id', 'int', 'NO', 'PRI', None, ''),
#  ('username', 'varchar(20)', 'YES', 'UNI', None, ''),
#  ('email', 'varchar(50)', 'YES', 'UNI', None, ''),
#  ('created_at', 'date', 'YES', '', None, '')]

# %%
# %%sql
# #c4-not null
# create table const_ex.notnulltb (User_id INT primary key , username varchar(20) unique,email varchar(50) unique,created_at date not null);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# []

# %%
# %%sql
# desc const_ex.notnulltb;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 4 rows affected.
# [('User_id', 'int', 'NO', 'PRI', None, ''),
#  ('username', 'varchar(20)', 'YES', 'UNI', None, ''),
#  ('email', 'varchar(50)', 'YES', 'UNI', None, ''),
#  ('created_at', 'date', 'NO', '', None, '')]

# %%
# %%sql
# insert into const_ex.notnulltb values
# (1,'Saud','saudjbr@gmail.com',null);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# (mysql.connector.errors.IntegrityError) 1048 (23000): Column 'created_at' cannot be null
# [SQL: insert into const_ex.notnulltb values
# (1,'Saud','saudjbr@gmail.com',null);]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
# %%sql
# select * from const_ex.notnulltb;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 2 rows affected.
# [(1, 'Saud', 'saudjbr@gmail.com', datetime.date(2026, 1, 20)),
#  (2, 'aysha', 'lofain@gmail.com', datetime.date(2026, 1, 20))]

# %%
# %%sql
# #c5-checkconstraint
# create table const_ex.checktb (Student_name varchar(30), Age int check(age>=18),Gender varchar(1) check(Gender in ('M','F') ));
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# []

# %%
# %%sql
# drop table const_ex.checktb
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# []

# %%
# %%sql
# insert into const_ex.checktb values
# ('Mahid',18,'m');
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 1 rows affected.
# []

# %%
# %%sql
# select * from const_ex.checktb;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 4 rows affected.
# [('Saud', 21, 'M'), ('Aysha', 21, 'F'), ('Mahid', 23, 'm'), ('Mahid', 18, 'm')]

# %%
# %%sql
# #foreign key
# create table const_ex.fortb (dept_id int primary key, dept_name varchar(10));
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# []

# %%
# %%sql
# create table const_Ex.fortb2
# (emp_id int primary key, emp_name varchar(10), dept_id int ,
# constraint fk_tab foreign key (dept_id) references const_ex.fortb(dept_id) ON DELETE CASCADE );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# []

# %%
# %%sql
# INSERT INTO const_ex.fortb VALUES
#
# (103,'DS');
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 1 rows affected.
# []

# %%
# %%sql
# SELECT * FROM const_ex.fortb;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 3 rows affected.
# [(101, 'AI'), (102, 'SD'), (103, 'DS')]

# %%
# %%sql
# INSERT INTO const_ex.fortb2 VALUES
# (203,'Safwan',103);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# (mysql.connector.errors.IntegrityError) 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`const_ex`.`fortb2`, CONSTRAINT `fk_tab` FOREIGN KEY (`dept_id`) REFERENCES `fortb` (`dept_id`) ON DELETE CASCADE)
# [SQL: INSERT INTO const_ex.fortb2 VALUES
# (203,'Safwan',103);]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
# %%sql
# SELECT * FROM const_ex.fortb2;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 3 rows affected.
# [(201, 'Saud', 101), (202, 'Aysha', 102), (203, 'Safwan', 103)]

# %%
# %%sql
# DELETE FROM const_ex.fortb WHERE dept_id=103;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 1 rows affected.
# []

# %%
# %%sql
# SELECT * FROM const_ex.fortb2;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 2 rows affected.
# [(201, 'Saud', 101), (202, 'Aysha', 102)]

# %%
# %%sql
# #c8
# CREATE TABLE const_ex.custb (customer_id int primary key, customer_name varchar(10),is_deleted boolean DEFAULT FALSE , deleted_at DATE null);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# []

# %%
# %%sql
# desc const_ex.custb;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 4 rows affected.
# [('customer_id', 'int', 'NO', 'PRI', None, ''),
#  ('customer_name', 'varchar(10)', 'YES', '', None, ''),
#  ('is_deleted', 'tinyint(1)', 'YES', '', '0', ''),
#  ('deleted_at', 'date', 'YES', '', None, '')]

# %%
# %%sql
# INSERT INTO const_ex.custb (customer_id,customer_name) VALUES
# (1,'Safwan'),
# (2,'Surender'),
# (3,'Harish');
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 3 rows affected.
# []

# %%
# %%sql
# select * FROM const_ex.custb;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 3 rows affected.
# [(1, 'Safwan', 0, None), (2, 'Surender', 0, None), (3, 'Harish', 0, None)]

# %%
c9

# %%
# %%sql
# UPDATE const_ex.custb set is_deleted= TRUE, deleted_at='2026-01-22' where customer_id=3;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 1 rows affected.
# []

# %%
# %%sql
# select * FROM const_ex.custb;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 3 rows affected.
# [(1, 'Safwan', 0, None),
#  (2, 'Surender', 0, None),
#  (3, 'Harish', 1, datetime.date(2026, 1, 22))]

# %%
# %%sql
# #c10
# select customer_id, customer_name from const_ex.custb where is_deleted= FALSE;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 2 rows affected.
# [(1, 'Safwan'), (2, 'Surender')]
