# %%
🧪 HANDS-ON PRACTICE (IDX1–IDX10)

👉 You write queries, I review like an interviewer.

IDX1

Create an index on department column.

IDX2

Create a composite index on (department, salary).

IDX3

Write a query that uses the composite index.

IDX4

Write a query that does NOT use the composite index.

IDX5

Use EXPLAIN to check if an index is used.

IDX6

Drop an index.

IDX7

Why does SELECT * reduce index efficiency?

IDX8

Difference between WHERE and HAVING in optimization.

IDX9

What is a covering index?

IDX10 (Interview Killer)

Why indexing a column with many duplicate values is inefficient?

# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:root@localhost/

# %%
# %%sql
# create database index_ex;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 1 rows affected.
# []

# %%
# %%sql
# create table index_ex.tb as
# select * from winf_ex.ranktb;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 12 rows affected.
# []

# %%
# %%sql
# select * from index_ex.tb;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 12 rows affected.
# [(1, 'Saud', 'AI', 75000, 25, 'Bangalore', datetime.date(2022, 6, 10)),
#  (2, 'Rahul', 'HR', 32000, 29, 'Chennai', datetime.date(2021, 1, 15)),
#  (3, 'Aisha', 'Data', 48000, 23, 'Hyderabad', datetime.date(2023, 9, 5)),
#  (4, 'Imran', 'AI', 62000, 27, 'Bangalore', datetime.date(2020, 3, 18)),
#  (5, 'Neha', 'Finance', 55000, 31, 'Mumbai', datetime.date(2019, 11, 22)),
#  (6, 'Arjun', 'Data', 39000, 26, 'Delhi', datetime.date(2024, 2, 14)),
#  (7, 'Kiran', 'HR', 28000, 24, 'Chennai', datetime.date(2023, 7, 1)),
#  (8, 'Zoya', 'AI', 45000, 22, 'Kochi', datetime.date(2024, 5, 20)),
#  (9, 'Sanjay', 'Finance', 67000, 35, 'Mumbai', datetime.date(2018, 8, 9)),
#  (10, 'Aman', 'Data', 52000, 28, 'Bangalore', datetime.date(2022, 12, 30)),
#  (11, 'Nikhil', 'AI', 80000, 30, 'Bangalore', datetime.date(2021, 10, 11)),
#  (12, 'Pooja', 'HR', 36000, 27, 'Delhi', datetime.date(2020, 4, 19))]

# %%
# %%sql
# #Create an index on department column.
# create index idx_dept on index_ex.tb(department);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# []

# %%
# %%sql
# create index idx_deptsal on index_ex.tb(department, salary);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# []

# %%
# %%sql
# #Write a query that uses the composite index.
# select * from index_ex.tb where department ='AI' and salary= 75000;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 1 rows affected.
# [(1, 'SIMPLE', 'tb', None, 'ref', 'idx_deptsal', 'idx_deptsal', '128', 'const,const', 1, 100.0, None)]

# %%
# %%sql
# select * from index_ex.tb where emp_name='saud';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 1 rows affected.
# [(1, 'SIMPLE', 'tb', None, 'ALL', None, None, None, None, 12, 10.0, 'Using where')]

# %%
# %%sql
# #Use EXPLAIN to check if an index is used.
# explain
#
# select * from index_ex.tb where department ='AI' and salary= 75000;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 1 rows affected.
# [(1, 'SIMPLE', 'tb', None, 'ref', 'idx_dept,idx_deptsal', 'idx_deptsal', '128', 'const,const', 1, 100.0, None)]

# %%
# %%sql
# EXPLAIN
#
# select * from index_ex.tb where emp_name='saud';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 1 rows affected.
# [(1, 'SIMPLE', 'tb', None, 'ALL', None, None, None, None, 12, 10.0, 'Using where')]

# %%
# %%sql
# drop index  idx_dept on index_ex.tb ;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# []
